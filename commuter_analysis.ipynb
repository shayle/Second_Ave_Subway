# %%
from sas7bdat import SAS7BDAT
import pandas as pd

# %%
with SAS7BDAT('chs2014_public.sas7bdat') as f:
    df = f.to_data_frame()

# %%
variables = ['commute_subway','commute_citybus','commute_expbus',
             'commute_bike','commute_walk','commute_car',
             'commute_taxi','commute_train','commute_ferry','commute_other','commute_walkbike',
             'uhf34','wheredaytime','imputed_povertygroup']

# %%
basic_replace = {1:'yes',
           2:'no',
           3:'Did not report walk or bike'}

# %%
df_commute = df[[i for i in variables]].replace(to_replace=replace)

# %%
df_commute[df_commute['uhf34']==21]
# Out:
#      commute_subway commute_citybus commute_expbus commute_bike commute_walk  \
# 7               yes              no             no           no           no
# 14              NaN             NaN            NaN          NaN          NaN
# 25              yes              no             no           no           no
# 50              NaN             NaN            NaN          NaN          NaN
# 51              NaN             NaN            NaN          NaN          NaN
# 54               no              no             no           no          yes
# 61              NaN             NaN            NaN          NaN          NaN
# 125             NaN             NaN            NaN          NaN          NaN
# 151             yes              no             no           no           no
# 159             NaN             NaN            NaN          NaN          NaN
# 183             NaN             NaN            NaN          NaN          NaN
# ...
